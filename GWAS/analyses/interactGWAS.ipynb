# %%
import pandas as pd
import gwaslab as gl

# %%
root = "/group/glastonbury/GWAS/F20208v3_DiffAE/select_latents_r80/nNs_Qntl_INF30_DiffAE128_5Sd_r80_discov_fullDSV3/SEXINTERACT/nNs_Qntl_WBRIT_INF30_DiffAE128_5Sd_r80_discov_SexInteract_fullDSV3_output/nNs_Qntl_WBRIT_INF30_DiffAE128_5Sd_r80_discov_SexInteract_fullDSV3/results/gwas"

sumstat = "S1701_Z53.gwas.regenie.gz"

# %%
df = pd.read_table(f"{root}/{sumstat}", sep="\t")

# %%
df
# Out:
#           CHROM    GENPOS                                                 ID  \
# 0             1     10511                                    rs534229142_G_A
# 1             1     10511                                    rs534229142_G_A
# 2             1     10511                                    rs534229142_G_A
# 3             1     10511                                    rs534229142_G_A
# 4             1     10616  1:10616_CCGCCGTTGCAAAGGCGCGCCG_C_CCGCCGTTGCAAA...
# ...         ...       ...                                                ...
# 61667919     22  51241386                                    rs568168135_C_G
# 61667920     22  51244237                                    rs575160859_C_T
# 61667921     22  51244237                                    rs575160859_C_T
# 61667922     22  51244237                                    rs575160859_C_T
# 61667923     22  51244237                                    rs575160859_C_T
#
# ...
